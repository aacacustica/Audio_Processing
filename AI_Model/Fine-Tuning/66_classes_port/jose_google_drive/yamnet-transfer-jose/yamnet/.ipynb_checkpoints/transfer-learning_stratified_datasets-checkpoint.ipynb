# %% [markdown]
# # YAMNET Transfer learning
#
#
# ## The typical transfer-learning workflow
#
# This leads us to how a typical transfer learning workflow can be implemented in Keras:
#
# * Instantiate a base model and load pre-trained weights into it.
# * Freeze all layers in the base model by setting trainable = False.
# * Create a new model on top of the output of one (or several) layers from the base model.
# * Train your new model on your new dataset.
#
# Note that an alternative, more lightweight workflow could also be:
#
# * Instantiate a base model and load pre-trained weights into it.
# * Run your new dataset through it and record the output of one (or several) layers from the base model. This is called feature extraction.
# * Use that output as input data for a new, smaller model.
# * A key advantage of that second workflow is that you only run the base model once on your data, rather than once per epoch of training. So it's a lot faster & cheaper.
#
#
# References:
# https://www.tensorflow.org/tutorials/audio/transfer_learning_audio

# %%
import pandas as pd
import tensorflow as tf 
import h5py
import os
import tensorflow_hub as hub
import resampy
import soundfile as sf
import librosa
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
import datetime
import glob
import resampy

# Model specific
import params as yamnet_params
import yamnet as yamnet_model
from IPython.display import Audio, display

print("running TF version",tf.__version__)
# Out:
# running TF version 2.9.2

# %%
df_class_map = pd.read_csv("yamnet_class_map.csv")
df_custom_class = pd.read_csv("category_map.csv", sep=";")

mid_dict = {mid:i for i, mid in enumerate(df_class_map["mid"].values)}
index_dict = {i:mid for i, mid in enumerate(df_class_map["mid"].values)}

custom_dict = {mid:i for i, mid in enumerate(df_custom_class["mid"].values)}

def mid_to_index(mid):
    return mid_dict[mid]

def index_to_mid(mid):
    return index_dict[mid]

# %%
# Clone model repo
#!git clone https://github.com/tensorflow/models.git
#%cd models/research/audioset/yamnet

# Download YAMNet data
#!curl -O https://storage.googleapis.com/audioset/yamnet.h5

# %%
# Set DATASET ROOT FOLDERS

eval_folder = "/Volumes/AAC_Book/AUDIOSET_STRONG/eval_16k/"
train_folder = "/Volumes/AAC_Book/AUDIOSET_STRONG/train_16k/"

assert os.path.exists(eval_folder), "Carpeta evaluacion no existe"
assert os.path.exists(train_folder), "Carpeta entrenamiento no existe"

# %% [markdown]
# # 1. Instantiate a base model and load pre-trained weights into it
#
# Load the YAMNET Base model and built a submodel that outputs the 1024 embeddings from the global average pooling 2d

# %%
# The graph is designed for a sampling rate of 16 kHz, but higher rates should work too.
# We also generate scores at a 10 Hz frame rate.
sr = 16000
params = yamnet_params.Params(sample_rate=sr, patch_hop_seconds=1)
print("Sample rate =", params.sample_rate)


# Set up the YAMNet model.
class_names = yamnet_model.class_names('yamnet_class_map.csv')
yamnet = yamnet_model.yamnet_frames_model(params)
yamnet.load_weights('yamnet.h5')
# Out:
# Sample rate = 16000
# Metal device set to: Apple M2
# 2023-03-28 12:18:35.324757: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-28 12:18:35.324996: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
embedding_layer = tf.keras.Model(inputs=yamnet.input,
                                 outputs=yamnet.get_layer('global_average_pooling2d').output)

embedding_layer.trainable = False

# %% [markdown]
# ## Read metada csv file
#
# We have to convert the label mid encodings to integers and then to one hot to serve as labels in a NN

# %%
N = 20
metadata_train = pd.read_csv(f"../data_stratified/train_stratified_{N}_class.csv")
metadata_eval = pd.read_csv(f"../data_stratified/eval_stratified_{N}_class.csv")
metadata_train
# Out:
#       index  Unnamed: 0          segment_id  start_time_seconds  \
# 0     39069      106185   2MjwmFnXCeY_80000               0.000
# 1     38889      105555   Ugz49bOoJTA_30000               0.008
# 2     38921      105695       HDX8gR5sl3w_0               0.086
# 3     39314      107016   8eGaCj0w6_k_11000               0.000
# 4     39225      106700   ffaRqnZADyA_60000               2.714
# ...     ...         ...                 ...                 ...
# 1135  47688      130736  AOXxtQ1XCj4_310000               1.378
# 1136  47723      130817   -SP3Tsk0WhI_70000               1.753
# 1137  47725      130823   BCkKq5XMxx0_21000               1.528
# 1138  47657      130660   HF8hy5katn0_10000               7.729
# 1139  47742      130871       PHTuu-BVdPY_0               4.352
#
#       end_time_seconds       label  duration_x              clip_id  \
# 0               10.000   /m/012f08      10.000   0x4b75b65da9d42ba3
# 1               10.000   /m/012f08       9.992   0x2e99d9231e339029
# 2                3.138   /m/012f08       3.052  -0x64990a6c36eb8444
# 3                9.189   /m/012f08       9.189  -0x17f52acb71ca2e80
# 4                9.488   /m/012f08       6.774  -0x7ab1a0016b513160
# ...                ...         ...         ...                  ...
# 1135             3.625  /t/dd00134       2.247   0x656bddb4a35e3764
# 1136             4.174  /t/dd00134       2.421  -0x39acdffd999ae585
# 1137             3.616  /t/dd00134       2.088    0xbbbca793ed2a2cd
# 1138             9.081  /t/dd00134       1.352   0x491c2f0421674134
# 1139             6.525  /t/dd00134       2.173    0x41c80dedc5f18f1
#
#            conjunto             filename  duration_y
# 0     entrenamiento   0x4b75b65da9d42ba3   10.000562
# 1     entrenamiento   0x2e99d9231e339029    9.973500
# 2     entrenamiento  -0x64990a6c36eb8444    3.053500
# 3     entrenamiento  -0x17f52acb71ca2e80   10.146562
# 4     entrenamiento  -0x7ab1a0016b513160    9.453500
# ...             ...                  ...         ...
# 1135  entrenamiento   0x656bddb4a35e3764    2.253938
# 1136  entrenamiento  -0x39acdffd999ae585    4.153500
# 1137  entrenamiento    0xbbbca793ed2a2cd    4.593500
# 1138  entrenamiento   0x491c2f0421674134    1.353500
# 1139  entrenamiento    0x41c80dedc5f18f1    2.161625
#
# [1140 rows x 11 columns]

# %% [markdown]
# We have to construct the audio path based on the location of the audio files, define a loading function that reads and audio file, check if it's mono and 16k

# %%
metadata_train["path"] = train_folder + metadata_train["clip_id"] + ".wav"
metadata_eval["path"] = eval_folder + metadata_eval["clip_id"] + ".wav"

# %%
def load_audio(filename):
    x, fs = sf.read(filename)
    
    if len(x.shape) > 1:
        x = np.mean(x, axis=1)
        
    #if fs != 16000:
        #x = resampy.resample(x,sr_orig=fs,sr_new=16000)
    return x

# %% [markdown]
# ## Feature extraction
#
# Run your new dataset through it and record the output of one (or several) layers from the base model. This is called feature extraction
#
# With the feature extractor model we have to build a new dataset that matches the shape of the embeddings with the label, remember that this feature extractor outputs a 1024 dimensional vector per second and we have a dataset of audios that have different duration. Then we have to repeat the label of audio according to the embedding shape.
#
# Note that we're saving the results in memory, this approach is valid for small to medium size datasets. For large datasets is needed to implement feature and training pipelines

# %%
metadata_train["label_id"] = metadata_train.apply(lambda x: custom_dict[x["label"]], axis=1)

filenames = metadata_train["path"]
targets = metadata_train["label_id"]
n_classes = 66 # fixed to the selection
embedding_size = 1024

all_embeddings = np.empty([1,embedding_size])
all_labels = np.zeros(1)
for file, label in zip(filenames, targets):
    x = load_audio(file)
    embeddings = embedding_layer(x)
    all_embeddings = np.concatenate( [all_embeddings, embeddings] )
    all_labels = np.concatenate( [all_labels,np.repeat(label,embeddings.shape[0])] )
    #print(all_embeddings.shape, all_labels.shape)

# %%
metadata_eval["label_id"] = metadata_eval.apply(lambda x: custom_dict[x["label"]], axis=1)

filenames = metadata_eval["path"]
targets = metadata_eval["label_id"]
n_classes = 66 # fixed to the selection
embedding_size = 1024

all_embeddings_eval = np.empty([1,embedding_size])
all_labels_eval = np.zeros(1)

for file, label in zip(filenames, targets):
    x = load_audio(file)
    embeddings = embedding_layer(x)
    all_embeddings_eval = np.concatenate( [all_embeddings_eval, embeddings] )
    all_labels_eval = np.concatenate( [all_labels_eval,np.repeat(label,embeddings.shape[0])] )
    #print(all_embeddings.shape, all_labels.shape)

# %%
# Plot embeddings to see the groupings

# %%
# As a sanity cheeck let's hear 5 random examples of this dataset


rand_sample = metadata_train.sample(5)

for i, clip in rand_sample.iterrows():
    x, fs = sf.read(clip["path"])
    scores, embeddings, spectrogram = yamnet(x)
    mean_scores = np.mean(scores,axis=0)
    print("prediction: ",class_names[np.argmax(mean_scores)])
    print(mean_scores.shape)
    print("ground_truth: ", class_names[mid_to_index(clip.label)])
    display(Audio(data=x,rate=fs))
# Out:
# prediction:  Bicycle bell
# (521,)
# ground_truth:  Clang
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# prediction:  Television
# (521,)
# ground_truth:  Vehicle horn, car horn, honking
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# prediction:  Vehicle
# (521,)
# ground_truth:  Engine
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# prediction:  Speech
# (521,)
# ground_truth:  Mechanical fan
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# prediction:  Silence
# (521,)
# ground_truth:  Squeak
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Build the custom model
#
# Using the extacted featured from the base model we will add a 128 dense layer plus a N_classes softmaz layer at the end

# %%
### Model #######

inputs = tf.keras.layers.Input(shape=(embedding_size), dtype=tf.float32, name='input_embedding')
dense = tf.keras.layers.Dense(128, name='Hidden_1',
                              activation="relu",
                               kernel_initializer='ones',
    kernel_regularizer=tf.keras.regularizers.L1(0.01),
    activity_regularizer=tf.keras.regularizers.L2(0.01),
                             )(inputs)
#dense = tf.keras.layers.Dense(64, name='Hidden_2', activation="relu")(dense)
outputs =  tf.keras.layers.Dense(n_classes, name="output", activation="softmax")(dense)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

##################

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
             metrics=["accuracy"],)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_embedding (InputLayer  [(None, 1024)]           0
#  )
#
#  Hidden_1 (Dense)            (None, 128)               131200
#
#  output (Dense)              (None, 66)                8514
#
# =================================================================
# Total params: 139,714
# Trainable params: 139,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_tf = tf.constant(all_embeddings, dtype=tf.float32)
y_tf = tf.keras.utils.to_categorical(all_labels, num_classes = n_classes)

x_val = tf.constant(all_embeddings_eval, dtype=tf.float32)
y_val = tf.keras.utils.to_categorical(all_labels_eval, num_classes = n_classes)

# %%
N=20
start_date = datetime.datetime.strftime( datetime.datetime.now(), format="%Y%m%d_%H:%M:%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=f"./logs_stratified/{start_date}_{N}",
                                                     )
model.fit(x=x_tf,
         y=y_tf,
         epochs=200,
          callbacks=[tensorboard_callback],
          validation_data=(x_val, y_val),
         batch_size=32)
# Out:
# Epoch 1/200
#  11/203 [>.............................] - ETA: 1s - loss: 4.2683 - accuracy: 0.0227
# 2023-03-28 13:19:27.518821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 202/203 [============================>.] - ETA: 0s - loss: 4.0196 - accuracy: 0.0729
# 2023-03-28 13:19:28.697486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 203/203 [==============================] - 3s 12ms/step - loss: 4.0192 - accuracy: 0.0730 - val_loss: 4.1058 - val_accuracy: 0.0591
# Epoch 2/200
# 203/203 [==============================] - 2s 10ms/step - loss: 3.5708 - accuracy: 0.1743 - val_loss: 3.9918 - val_accuracy: 0.0922
# Epoch 3/200
# 203/203 [==============================] - 2s 10ms/step - loss: 3.2419 - accuracy: 0.2336 - val_loss: 3.8692 - val_accuracy: 0.1156
# Epoch 4/200
# 203/203 [==============================] - 2s 9ms/step - loss: 3.0237 - accuracy: 0.2629 - val_loss: 3.7678 - val_accuracy: 0.1280
# Epoch 5/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.8700 - accuracy: 0.2873 - val_loss: 3.6854 - val_accuracy: 0.1347
# Epoch 6/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.7581 - accuracy: 0.3029 - val_loss: 3.6199 - val_accuracy: 0.1404
# Epoch 7/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.6716 - accuracy: 0.3165 - val_loss: 3.5919 - val_accuracy: 0.1392
# Epoch 8/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.6012 - accuracy: 0.3268 - val_loss: 3.5758 - val_accuracy: 0.1394
# Epoch 9/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.5440 - accuracy: 0.3360 - val_loss: 3.5493 - val_accuracy: 0.1408
# Epoch 10/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.4973 - accuracy: 0.3449 - val_loss: 3.5396 - val_accuracy: 0.1435
# Epoch 11/200
# 203/203 [==============================] - 2s 11ms/step - loss: 2.4549 - accuracy: 0.3488 - val_loss: 3.5238 - val_accuracy: 0.1434
# Epoch 12/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.4190 - accuracy: 0.3540 - val_loss: 3.5150 - val_accuracy: 0.1456
# Epoch 13/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.3845 - accuracy: 0.3604 - val_loss: 3.5187 - val_accuracy: 0.1438
# Epoch 14/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.3563 - accuracy: 0.3653 - val_loss: 3.4961 - val_accuracy: 0.1448
# Epoch 15/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.3273 - accuracy: 0.3727 - val_loss: 3.4979 - val_accuracy: 0.1445
# Epoch 16/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.2993 - accuracy: 0.3800 - val_loss: 3.4956 - val_accuracy: 0.1452
# Epoch 17/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.2737 - accuracy: 0.3829 - val_loss: 3.5094 - val_accuracy: 0.1441
# Epoch 18/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.2509 - accuracy: 0.3932 - val_loss: 3.5261 - val_accuracy: 0.1415
# Epoch 19/200
# 203/203 [==============================] - 2s 9ms/step - loss: 2.2295 - accuracy: 0.3977 - val_loss: 3.5148 - val_accuracy: 0.1426
# Epoch 20/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.2071 - accuracy: 0.4003 - val_loss: 3.5091 - val_accuracy: 0.1412
# Epoch 21/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2.1866 - accuracy: 0.4039 - val_loss: 3.5240 - val_accuracy: 0.1420
# Epoch 22/200
# 203/203 [==============================] - 2s 10ms/step - loss: 2
200
# 203/203 [==============================] - 2s 10ms/step - loss: 1.0119 - accuracy: 0.7414 - val_loss: 4.8292 - val_accuracy: 0.1122
# Epoch 174/200
# 203/203 [==============================] - 2s 10ms/step - loss: 1.0073 - accuracy: 0.7471 - val_loss: 4.8388 - val_accuracy: 0.1142
# Epoch 175/200
# 203/203 [==============================] - 2s 10ms/step - loss: 1.0046 - accuracy: 0.7443 - val_loss: 4.8264 - val_accuracy: 0.1152
# Epoch 176/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9990 - accuracy: 0.7491 - val_loss: 4.8170 - val_accuracy: 0.1152
# Epoch 177/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9960 - accuracy: 0.7494 - val_loss: 4.8526 - val_accuracy: 0.1139
# Epoch 178/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9917 - accuracy: 0.7502 - val_loss: 4.8571 - val_accuracy: 0.1137
# Epoch 179/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9874 - accuracy: 0.7514 - val_loss: 4.8590 - val_accuracy: 0.1160
# Epoch 180/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9826 - accuracy: 0.7537 - val_loss: 4.8691 - val_accuracy: 0.1142
# Epoch 181/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9791 - accuracy: 0.7545 - val_loss: 4.8680 - val_accuracy: 0.1165
# Epoch 182/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9752 - accuracy: 0.7562 - val_loss: 4.9109 - val_accuracy: 0.1137
# Epoch 183/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9718 - accuracy: 0.7573 - val_loss: 4.8972 - val_accuracy: 0.1152
# Epoch 184/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9670 - accuracy: 0.7564 - val_loss: 4.9239 - val_accuracy: 0.1137
# Epoch 185/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9633 - accuracy: 0.7585 - val_loss: 4.9169 - val_accuracy: 0.1153
# Epoch 186/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9597 - accuracy: 0.7590 - val_loss: 4.9226 - val_accuracy: 0.1147
# Epoch 187/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9545 - accuracy: 0.7587 - val_loss: 4.9423 - val_accuracy: 0.1160
# Epoch 188/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9510 - accuracy: 0.7622 - val_loss: 4.9748 - val_accuracy: 0.1146
# Epoch 189/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9486 - accuracy: 0.7601 - val_loss: 4.9550 - val_accuracy: 0.1168
# Epoch 190/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9429 - accuracy: 0.7622 - val_loss: 4.9611 - val_accuracy: 0.1137
# Epoch 191/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9405 - accuracy: 0.7639 - val_loss: 4.9770 - val_accuracy: 0.1150
# Epoch 192/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9352 - accuracy: 0.7656 - val_loss: 4.9831 - val_accuracy: 0.1141
# Epoch 193/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9316 - accuracy: 0.7679 - val_loss: 5.0050 - val_accuracy: 0.1139
# Epoch 194/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9290 - accuracy: 0.7690 - val_loss: 4.9977 - val_accuracy: 0.1168
# Epoch 195/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9250 - accuracy: 0.7675 - val_loss: 5.0095 - val_accuracy: 0.1142
# Epoch 196/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9211 - accuracy: 0.7700 - val_loss: 5.0406 - val_accuracy: 0.1137
# Epoch 197/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9169 - accuracy: 0.7726 - val_loss: 5.0370 - val_accuracy: 0.1142
# Epoch 198/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9130 - accuracy: 0.7723 - val_loss: 5.0531 - val_accuracy: 0.1150
# Epoch 199/200
# 203/203 [==============================] - 2s 9ms/step - loss: 0.9097 - accuracy: 0.7721 - val_loss: 5.0761 - val_accuracy: 0.1143
# Epoch 200/200
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9064 - accuracy: 0.7744 - val_loss: 5.0899 - val_accuracy: 0.1139

# %%
# !tensorboard --logdir="./logs"
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.9.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
all_embeddings.shape

print(all_labels.shape)
# Out:
# (96947,)

# %% [markdown]
# ## Tf datasets approach

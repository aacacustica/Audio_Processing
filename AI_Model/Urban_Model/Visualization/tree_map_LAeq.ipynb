# %%
import pandas as pd
import numpy as np
import os
import datetime
import ast

import subprocess

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
pio.renderers.default='notebook'
import plotly.express as px

import matplotlib.colors as mcolors
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Constants

# %%
COLOR_PALLET_L2 = {
            'Other human': '#2986cc', # BLUE
            'Electro-mechanical': '#cc0000', # RED
            'Voice': '#6aa84f', #  green 6aa84f
            'Motorised transport': '#ffa500', # orange
            'Geonature': '#8e7cc3', # PURPLE
            'Animal': '#9b5f00', # BROWN
            'Music': '#d172a4', # PINK
            'Background': '#000000', # BLACK
            'Other Sounds': '#c9d631', # yellow
            'Social/communal': '#d8cbf8', # Light purple
            'Human movement': '#40b674', # light green 40b674
        }

COLOR_PALLET_L3 = {
    
}

cmap_dict = sns.color_palette(palette=["#C8FFC8", "#00C800", "#007800", "#FFFF00", "#FFC878", "#FF9600", "#FF0000", "#780000", "#FF00FF", "#8C3CFF", "#000078"], n_colors=11)
hex_colors = [mcolors.to_hex(color) for color in cmap_dict]
custom_color_scale = [[i/len(hex_colors), color] for i, color in enumerate(hex_colors)]
custom_color_scale.append([1, hex_colors[-1]])

# %% [markdown]
# # Functions Tools

# %%
def leq(levels):
    levels = levels[~np.isnan(levels)]
    l = np.array(levels)
    return 10 * np.log10(np.mean(np.power(10, l / 10)))

def extract_location(file_path):
    file_name = os.path.basename(file_path)
    parts = file_name.split("_")
   
    if len(parts) > 2:
        return parts[2]
    else:
        return parts[0]
    
def postprocessing_df(df_preds):
    print(len(df_preds.columns))
    if len(df_preds.columns) != 5:
        df_preds.drop(columns=['classes_custom', 'probabilities_custom', 'sum_probs_custom', 'sum_probs_original'],inplace=True)
    else:
        df_preds.drop(columns=['classes_custom'],inplace=True)
    
    df_preds.rename(columns={'classes_original':'classes'}, inplace=True)
    df_preds['classes'] = df_preds['classes'].apply(ast.literal_eval)
    
    return df_preds

def remove_unnamed_columns(df_preds):
    df_preds = df_preds.loc[:, ~df_preds.columns.str.contains('^Unnamed')]
    df_preds = df_preds.drop(columns=['Brown_Level_1'])
    df_preds = df_preds.drop(columns=['index'])
    return df_preds

def insert_time(df_preds):
    df_preds['date'] = pd.to_datetime(df_preds['datetime'])

    df_preds['year'] = df_preds.apply(lambda x: x['date'].year, axis= 1)
    df_preds['month'] = df_preds.apply(lambda x: x['date'].month, axis= 1)
    df_preds['day'] = df_preds.apply(lambda x: x['date'].day, axis= 1)

    df_preds['day_name'] = df_preds.apply(lambda x: x['date'].day_name(), axis= 1)
    df_preds['weekday'] = df_preds.apply(lambda x: x['date'].weekday(), axis= 1)
    
    df_preds['hour'] = df_preds.apply(lambda x: x['date'].hour, axis= 1)
    df_preds['hour_min'] = df_preds.apply(lambda x: str(x['date'].hour) + '_' + str(x['date'].minute),axis=1)
    
    df_preds['time'] = df_preds.apply(lambda x: x['date'].time(),axis=1)
    
    return df_preds

def print_end_start_date(df):
    start_date = df.sort_values('date')['date'].iloc[0]
    end_date = df.sort_values('date')['date'].iloc[-1]
    printing = 'Inicio Monitoreo: {} \nFinal Monitoreo: {}'.format(start_date,end_date)
    return printing

def index_and_explode(df):
    df.set_index('time',inplace=True)
    df = df.explode('classes')
    df['display_name'] = df['classes']
    df['number'] = 1   
    return df

def merge_dataframes(df, union):
    df = df.merge(union,how='left',on='display_name')
    return df

def remove_label(df, column, label):
    df_no_label = df[df[column] != label]
    return df_no_label, label

# sort by time column called datetime
def sort_df(df):
    df.sort_values(by=['datetime'], inplace=True)
    return df

def output_dir(path: str):
    # get the abs path and remove the last element
    path = os.path.abspath(path).split("\\")[:-2]
    path = "/".join(path)
    
    visualization_dir = path + "/Visualizations"
    os.makedirs(visualization_dir, exist_ok=True)
    
    return visualization_dir

# get the last git tag version
def list_git_tags():
    try:
        tags = tags = subprocess.check_output(["git", "tag"]).strip().decode()
        return tags.split('\n')
    except subprocess.CalledProcessError:
        return None
    
def select_tag(tags):
    for i, tag in enumerate(tags):
        print(f"{i}: {tag}")
    choice = int(input("Select the tag to use: "))
    tag_selected = tags[choice]
    # replace "." with "_" to be able to use it as a file name
    tag_selected = tag_selected.replace(".", "_")
        
    return tag_selected

def get_stable_version():
    tags = list_git_tags()
    # get the latest stable version
    tag_selected = tags[-1]
    print(f"Latest stable version with period: {tag_selected}")
    # replace "." with "_" to be able to use it as a file name
    tag_selected = tag_selected.replace(".", "_")
    
    print(f"Latest stable version with underscore: {tag_selected}")
    
    return tag_selected

stable_version = get_stable_version()
# Out:
# Latest stable version with period: v1.0
# Latest stable version with underscore: v1_0

# %% [markdown]
# # Open YAMNet Class Map

# %%
yammnet_class_map = r"C:\Users\GIS2\Documents\santi\GitHub\AAC\AI_Model\Urban_Model\taxonomy_mapping\yamnet_class_AAC_v1_0.csv"
df_audioset = pd.read_csv(yammnet_class_map,sep=';')
df_audioset = remove_unnamed_columns(df_audioset)
df_audioset
# Out:
#             mid                display_name iso_taxonomy    Brown_Level_2  \
# 0      /m/09x0r                      Speech        Voice            Voice
# 1      /m/0ytgt  Child speech, kid speaking        Voice            Voice
# 2     /m/01h8n0                Conversation        Voice            Voice
# 3     /m/02qldy        Narration, monologue        Voice            Voice
# 4     /m/0261r1                    Babbling        Voice            Voice
# ..          ...                         ...          ...              ...
# 516  /m/07p_0gm                   Throbbing   Background     Other Sounds
# 517   /m/01jwx6                   Vibration   Background     Other Sounds
# 518    /m/07c52                  Television   Background  Social/communal
# 519    /m/06bz3                       Radio   Background  Social/communal
# 520   /m/07hvw1             Field recording   Background  Social/communal
#
#     Brown_Level_3
# 0          speech
# 1          speech
# 2          speech
# 3          speech
# 4          speech
# ..            ...
# 516         noise
# 517         noise
# 518      domestic
# 519      domestic
# 520         noise
#
# [521 rows x 5 columns]

# %% [markdown]
# ## Check classes to asign colours to them

# %%
# print unique values in columns
print(f"Unique classes for Brown_Level_2 [ {len(df_audioset['Brown_Level_2'].unique())} ]")
print(df_audioset['Brown_Level_2'].unique())

print(f"\nUnique classes for Brown_Level_3 [ {len(df_audioset['Brown_Level_3'].unique())} ]")
print(df_audioset['Brown_Level_3'].unique())
# Out:
# Unique classes for Brown_Level_2 [ 11 ]
# ['Voice' 'Other human' 'Human movement' 'Animal' 'Electro-mechanical'
#  'Music' 'Geonature' 'Other Sounds' 'Motorised transport'
#  'Social/communal' 'Background']
#
# Unique classes for Brown_Level_3 [ 34 ]
# ['speech' 'laughter' 'Crying' 'Voice' 'Other human' 'singing' 'footsteps'
#  'Animal' 'Domestic Animal' 'Steam' 'Farm Animal' 'wildlife' 'Music'
#  'wind' 'thunder' 'water' 'Other Sounds' 'roadway traffic'
#  'marine traffic' 'alarms' 'rail traffic' 'air traffic' 'non motorized'
#  'Engine' 'Tool' 'domestic' 'alarm' 'Machine' 'blasting/gunshot'
#  'fireworks' 'Silence' 'Background people' 'Background Env' 'noise']

# %% [markdown]
# # Open the SPL file

# %%
path_spl = input("Enter the path to the SPL file: ")
path_spl = path_spl.replace('"', '')

# make visualization directory
visualization_dir = output_dir(path_spl)

# # get the location
title = extract_location(path_spl)

# get the csv
df_spl = pd.read_csv(path_spl)
df_spl = df_spl[['filename', 'date', 'LA', 'LC', 'LZ']]
df_spl
# Out:
#                 filename                 date     LA     LC     LZ
# 0    20231211_153450.wav  2023-12-11 15:34:50  70.23  76.01  76.12
# 1    20231211_153450.wav  2023-12-11 15:34:51  69.91  75.82  75.94
# 2    20231211_153450.wav  2023-12-11 15:34:52  70.26  75.70  75.83
# 3    20231211_153450.wav  2023-12-11 15:34:53  70.17  76.00  76.12
# 4    20231211_153450.wav  2023-12-11 15:34:54  70.20  75.78  75.86
# ..                   ...                  ...    ...    ...    ...
# 895  20231211_153450.wav  2023-12-11 15:49:45  85.27  89.43  89.47
# 896  20231211_153450.wav  2023-12-11 15:49:46  86.23  89.99  90.06
# 897  20231211_153450.wav  2023-12-11 15:49:47  83.40  87.09  87.19
# 898  20231211_153450.wav  2023-12-11 15:49:48  80.02  83.68  83.75
# 899  20231211_153450.wav  2023-12-11 15:49:49  77.43  81.04  81.09
#
# [900 rows x 5 columns]

# %% [markdown]
# # Open the Prediction file

# %%
path_input = input("Enter the path to the PREDICTIONS file: ")
path_input = path_input.replace('"', '')

# make visualization directory
visualization_dir = output_dir(path_input)
# get the location
title = extract_location(path_input)

# get the csv
df_prediction = pd.read_csv(path_input)

df_prediction
# Out:
#                     file             datetime  \
# 0    20231211_153450.WAV  2023-12-11 15:34:50
# 1    20231211_153450.WAV  2023-12-11 15:34:51
# 2    20231211_153450.WAV  2023-12-11 15:34:52
# 3    20231211_153450.WAV  2023-12-11 15:34:53
# 4    20231211_153450.WAV  2023-12-11 15:34:54
# ..                   ...                  ...
# 895  20231211_153450.WAV  2023-12-11 15:49:45
# 896  20231211_153450.WAV  2023-12-11 15:49:46
# 897  20231211_153450.WAV  2023-12-11 15:49:47
# 898  20231211_153450.WAV  2023-12-11 15:49:48
# 899  20231211_153450.WAV  2023-12-11 15:49:49
#
#                                       classes_original  \
# 0               ['Vehicle', 'Rail transport', 'Train']
# 1               ['Vehicle', 'Rail transport', 'Train']
# 2    ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 3                   ['Vehicle', 'Bicycle', 'Aircraft']
# 4                      ['Vehicle', 'Ship', 'Aircraft']
# ..                                                 ...
# 895  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 896  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 897  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 898  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 899  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
#
#                     probabilities_original
# 0         [0.7637054, 0.42956, 0.41159457]
# 1      [0.34616104, 0.17398019, 0.1715938]
# 2     [0.36263642, 0.20404567, 0.11580885]
# 3    [0.37071517, 0.12847383, 0.056504596]
# 4    [0.31615925, 0.12974216, 0.094931796]
# ..                                     ...
# 895    [0.9029716, 0.18985157, 0.17426494]
# 896     [0.8366037, 0.22521576, 0.1470383]
# 897    [0.7754757, 0.21422377, 0.18403114]
# 898     [0.770058, 0.34419206, 0.26134366]
# 899  [0.59305316, 0.103161864, 0.07410896]
#
# [900 rows x 4 columns]

# %% [markdown]
# ## Now we are ready to go

# %% [markdown]
# # Join DataFrames in a single one

# %%
#join the spl and prediction dataframes by date
df_spl['date'] = pd.to_datetime(df_spl['date'])
df_prediction['datetime'] = pd.to_datetime(df_prediction['datetime'])

# Merge the dataframes on the datetime columns
df_merged = pd.merge(df_spl, df_prediction, left_on='date', right_on='datetime')

df_merged = df_merged.drop(columns=['datetime', 'file'])

df_merged
# Out:
#                 filename                date     LA     LC     LZ  \
# 0    20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 1    20231211_153450.wav 2023-12-11 15:34:51  69.91  75.82  75.94
# 2    20231211_153450.wav 2023-12-11 15:34:52  70.26  75.70  75.83
# 3    20231211_153450.wav 2023-12-11 15:34:53  70.17  76.00  76.12
# 4    20231211_153450.wav 2023-12-11 15:34:54  70.20  75.78  75.86
# ..                   ...                 ...    ...    ...    ...
# 895  20231211_153450.wav 2023-12-11 15:49:45  85.27  89.43  89.47
# 896  20231211_153450.wav 2023-12-11 15:49:46  86.23  89.99  90.06
# 897  20231211_153450.wav 2023-12-11 15:49:47  83.40  87.09  87.19
# 898  20231211_153450.wav 2023-12-11 15:49:48  80.02  83.68  83.75
# 899  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
#
#                                       classes_original  \
# 0               ['Vehicle', 'Rail transport', 'Train']
# 1               ['Vehicle', 'Rail transport', 'Train']
# 2    ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 3                   ['Vehicle', 'Bicycle', 'Aircraft']
# 4                      ['Vehicle', 'Ship', 'Aircraft']
# ..                                                 ...
# 895  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 896  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 897  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 898  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
# 899  ['Vehicle', 'Aircraft', 'Fixed-wing aircraft, ...
#
#                     probabilities_original
# 0         [0.7637054, 0.42956, 0.41159457]
# 1      [0.34616104, 0.17398019, 0.1715938]
# 2     [0.36263642, 0.20404567, 0.11580885]
# 3    [0.37071517, 0.12847383, 0.056504596]
# 4    [0.31615925, 0.12974216, 0.094931796]
# ..                                     ...
# 895    [0.9029716, 0.18985157, 0.17426494]
# 896     [0.8366037, 0.22521576, 0.1470383]
# 897    [0.7754757, 0.21422377, 0.18403114]
# 898     [0.770058, 0.34419206, 0.26134366]
# 899  [0.59305316, 0.103161864, 0.07410896]
#
# [900 rows x 7 columns]

# %% [markdown]
# ## Explode it and align the prediction with its probability

# %%
df_merged['classes_original'] = df_merged['classes_original'].apply(ast.literal_eval)
df_merged['probabilities_original'] = df_merged['probabilities_original'].apply(ast.literal_eval)

df_exploded_classes = df_merged.explode('classes_original')
df_exploded = df_merged.apply(lambda x: x.explode() if x.name in ['classes_original', 'probabilities_original'] else x)

df_exploded
# Out:
#                 filename                date     LA     LC     LZ  \
# 0    20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 0    20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 0    20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 1    20231211_153450.wav 2023-12-11 15:34:51  69.91  75.82  75.94
# 1    20231211_153450.wav 2023-12-11 15:34:51  69.91  75.82  75.94
# ..                   ...                 ...    ...    ...    ...
# 898  20231211_153450.wav 2023-12-11 15:49:48  80.02  83.68  83.75
# 898  20231211_153450.wav 2023-12-11 15:49:48  80.02  83.68  83.75
# 899  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
# 899  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
# 899  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
#
#                   classes_original probabilities_original
# 0                          Vehicle               0.763705
# 0                   Rail transport                0.42956
# 0                            Train               0.411595
# 1                          Vehicle               0.346161
# 1                   Rail transport                0.17398
# ..                             ...                    ...
# 898                       Aircraft               0.344192
# 898  Fixed-wing aircraft, airplane               0.261344
# 899                        Vehicle               0.593053
# 899                       Aircraft               0.103162
# 899  Fixed-wing aircraft, airplane               0.074109
#
# [2700 rows x 7 columns]

# %%
df_exploded['display_name'] = df_exploded['classes_original']
df_all = df_exploded.merge(df_audioset, how='left', on='display_name')
df_all
# Out:
#                  filename                date     LA     LC     LZ  \
# 0     20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 1     20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 2     20231211_153450.wav 2023-12-11 15:34:50  70.23  76.01  76.12
# 3     20231211_153450.wav 2023-12-11 15:34:51  69.91  75.82  75.94
# 4     20231211_153450.wav 2023-12-11 15:34:51  69.91  75.82  75.94
# ...                   ...                 ...    ...    ...    ...
# 2695  20231211_153450.wav 2023-12-11 15:49:48  80.02  83.68  83.75
# 2696  20231211_153450.wav 2023-12-11 15:49:48  80.02  83.68  83.75
# 2697  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
# 2698  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
# 2699  20231211_153450.wav 2023-12-11 15:49:49  77.43  81.04  81.09
#
#                    classes_original probabilities_original  \
# 0                           Vehicle               0.763705
# 1                    Rail transport                0.42956
# 2                             Train               0.411595
# 3                           Vehicle               0.346161
# 4                    Rail transport                0.17398
# ...                             ...                    ...
# 2695                       Aircraft               0.344192
# 2696  Fixed-wing aircraft, airplane               0.261344
# 2697                        Vehicle               0.593053
# 2698                       Aircraft               0.103162
# 2699  Fixed-wing aircraft, airplane               0.074109
#
#                        display_name       mid     iso_taxonomy  \
# 0                           Vehicle  /m/07yv9  Roadway traffic
# 1                    Rail transport  /m/06d_3     Rail traffic
# 2                             Train  /m/07jdr     Rail traffic
# 3                           Vehicle  /m/07yv9  Roadway traffic
# 4                    Rail transport  /m/06d_3     Rail traffic
# ...                             ...       ...              ...
# 2695                       Aircraft   /m/0k5j      Air traffic
# 2696  Fixed-wing aircraft, airplane  /m/0cmf2      Air traffic
# 2697                        Vehicle  /m/07yv9  Roadway traffic
# 2698                       Aircraft   /m/0k5j      Air traffic
# 2699  Fixed-wing aircraft, airplane  /m/0cmf2      Air traffic
#
#             Brown_Level_2    Brown_Level_3
# 0     Motorised transport  roadway traffic
# 1     Motorised transport     rail traffic
# 2     Motorised transport     rail traffic
# 3     Motorised transport  roadway traffic
# 4     Motorised transport     rail traffic
# ...                   ...              ...
# 2695  Motorised transport      air traffic
# 2696  Motorised transport      air traffic
# 2697  Motorised transport  roadway traffic
# 2698  Motorised transport      air traffic
# 2699  Motorised transport      air traffic
#
# [2700 rows x 12 columns]

# %% [markdown]
# # Plotting Section

# %%
display_name = 'display_name'
iso_taxonomy = 'iso_taxonomy'
original_classes = 'classes_original'

brown_1 = 'Brown_Level_1'
brown_2 = 'Brown_Level_2'
brown_3 = 'Brown_Level_3'

class_to_plot = brown_2

# %% [markdown]
# ## Tree Map Representation

# %%
grouped_df = df_all.groupby([class_to_plot, original_classes]).size().reset_index(name='number')

fig = px.treemap(grouped_df, 
                 path=[class_to_plot, original_classes], 
                 values='number',
                 color=class_to_plot,
                 color_discrete_map=COLOR_PALLET_L2
                )

fig.update_layout(title='Title')
fig.show()
# Out:
# <div>                            <div id="3d8da60f-9b96-47e3-b5a3-664e1da99982" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d8da60f-9b96-47e3-b5a3-664e1da99982")) {                    Plotly.newPlot(                        "3d8da60f-9b96-47e3-b5a3-664e1da99982",                        [{"branchvalues":"total","customdata":[["Electro-mechanical"],["Electro-mechanical"],["Motorised transport"],["Motorised transport"],["Animal"],["Other Sounds"],["Human movement"],["Motorised transport"],["Motorised transport"],["Animal"],["Social/communal"],["Social/communal"],["Electro-mechanical"],["Electro-mechanical"],["Social/communal"],["Social/communal"],["Animal"],["Motorised transport"],["Social/communal"],["Motorised transport"],["Other Sounds"],["Motorised transport"],["Electro-mechanical"],["Motorised transport"],["Other Sounds"],["Motorised transport"],["Background"],["Background"],["Other Sounds"],["Voice"],["Music"],["Motorised transport"],["Motorised transport"],["Social/communal"],["Electro-mechanical"],["Electro-mechanical"],["Animal"],["Other Sounds"],["Motorised transport"],["Background"],["Electro-mechanical"],["Animal"],["Motorised transport"],["Motorised transport"],["Motorised transport"],["Voice"],["Other Sounds"],["Social/communal"],["Human movement"],["Motorised transport"],["Music"],["Other Sounds"],["Animal"],["Geonature"],["Other human"],["Motorised transport"],["Motorised transport"],["Motorised transport"],["Other Sounds"],["Other Sounds"],["Other Sounds"],["Other Sounds"],["Animal"],["Geonature"],["Geonature"],["Animal"],["Background"],["Electro-mechanical"],["Geonature"],["Human movement"],["Motorised transport"],["Music"],["Other Sounds"],["Other human"],["Social/communal"],["Voice"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>number=%{value}<br>parent=%{parent}<br>id=%{id}<br>Brown_Level_2=%{customdata[0]}<extra></extra>","ids":["Electro-mechanical/Accelerating, revving, vroom","Electro-mechanical/Air conditioning","Motorised transport/Aircraft","Motorised transport/Aircraft engine","Animal/Animal","Other Sounds/Arrow","Human movement/Bicycle","Motorised transport/Boat, Water vehicle","Motorised transport/Bus","Animal/Buzz","Social/communal/Firecracker","Social/communal/Field recording","Electro-mechanical/Engine","Electro-mechanical/Explosion","Social/communal/Door","Social/communal/Electric shaver, electric razor","Animal/Clip-clop","Motorised transport/Car","Social/communal/Fireworks","Motorised transport/Fixed-wing aircraft, airplane","Other Sounds/Gurgling","Motorised transport/Helicopter","Electro-mechanical/Heavy engine (low frequency)","Motorised transport/Motorcycle","Other Sounds/Pump (liquid)","Motorised transport/Propeller, airscrew","Background/Outside, urban or manmade","Background/Outside, rural or natural","Other Sounds/Noise","Voice/Narration, monologue","Music/Music","Motorised transport/Motorboat, speedboat","Motorised transport/Motor vehicle (road)","Social/communal/Microwave oven","Electro-mechanical/Mechanisms","Electro-mechanical/Mechanical fan","Animal/Livestock, farm animals, working animals","Other Sounds/Liquid","Motorised transport/Jet engine","Background/Inside, small room","Electro-mechanical/Idling","Animal/Horse","Motorised transport/Rail transport","Motorised transport/Railroad car, train wagon","Motorised transport/Subway, metro, underground","Voice/Speech","Other Sounds/Sound effect","Social/communal/Slam","Human movement/Skateboard","Motorised transport/Ship","Music/Scary music","Other Sounds/Rumble","Animal/Rattle","Geonature/Rain","Other human/Sigh","Motorised transport/Train","Motorised transport/Truck","Motorised transport/Vehicle","Other Sounds/Vibration","Other Sounds/Whack, thwack","Other Sounds/W ...

# %% [markdown]
# ## Power Average Sound Pressure Level (LAeq)

# %%
grouped_df = df_all.groupby(class_to_plot).agg(
    number=(original_classes, 'size'),
    LAeq=('LA', lambda x: leq(x))
).reset_index()

fig = px.treemap(grouped_df, 
                 path=[class_to_plot],  
                 values='number',
                 color='LAeq',
                 color_continuous_scale=custom_color_scale,
                 range_color=[30, 85],
                 hover_data={'LAeq': True, 'number': True},
                 custom_data=['LAeq']
                )

fig.update_layout(title='Power Average Sound Pressure Level (LAeq)')
fig.update_traces(hovertemplate='<b>%{label}</b><br>LAeq: %{customdata[0]:.2f} dB<br>Count: %{value}')
fig.update_traces(texttemplate='%{label}<br><br>LAeq: %{customdata[0]:.2f} dB')

fig.show()
# Out:
# <div>                            <div id="3d9f9b79-d457-461c-8e06-a7806772e8ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d9f9b79-d457-461c-8e06-a7806772e8ad")) {                    Plotly.newPlot(                        "3d9f9b79-d457-461c-8e06-a7806772e8ad",                        [{"branchvalues":"total","customdata":[[75.28888103488347,12.0],[74.02114904463426,55.0],[79.83624008381838,27.0],[73.00445447687567,3.0],[78.34386522786596,17.0],[72.98059520422684,2468.0],[69.20072622281717,9.0],[72.57349109971638,57.0],[73.53,1.0],[78.99546713043975,26.0],[72.57359247410326,25.0]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{label}</b><br>LAeq: %{customdata[0]:.2f} dB<br>Count: %{value}","ids":["Animal","Background","Electro-mechanical","Geonature","Human movement","Motorised transport","Music","Other Sounds","Other human","Social/communal","Voice"],"labels":["Animal","Background","Electro-mechanical","Geonature","Human movement","Motorised transport","Music","Other Sounds","Other human","Social/communal","Voice"],"marker":{"coloraxis":"coloraxis","colors":[75.28888103488347,74.02114904463426,79.83624008381838,73.00445447687567,78.34386522786596,72.98059520422684,69.20072622281717,72.57349109971638,73.53,78.99546713043975,72.57359247410326]},"name":"","parents":["","","","","","","","","","",""],"values":[12,55,27,3,17,2468,9,57,1,26,25],"type":"treemap","texttemplate":"%{label}<br><br>LAeq: %{customdata[0]:.2f} dB"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %% [markdown]
# # 0.1 Pass by usando medidas de aforadores automáticos
# A continuación se tratará de extraer el pass by usando los datos de un sonómetro en continuo que
# esta en simultaneo con una estación aforadora. El objetivo es relacionar la información de niveles
# de ruido cada segundo con las detecciones de pasos y velocidades que entrega la estación aforadora

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
plt.style.use("bmh")
# %matplotlib inline

# %%
def leq(levels:np.ndarray)->float:
    levels = levels[~np.isnan(levels)]
    l = np.array(levels)
    return 10*np.log10(np.mean(np.power(10,l/10)))

# %% [markdown]
# # 0.2 Lectura de datos de la estación aforadora
# El rada entrega información de dirección de circulación, velocidad y tipo de vehiculo según longitud
# entre las siguientes clases:
# * 1:bicis y motos
# * 2:turismos
# * 3:camión
# * 4:camión largo

# %%
# df = pd.read_csv("20230203.CSV", sep=";")
# file_path = r"\\192.168.205.117\AAC_Server\TRAFICO\REGISTRO_RADAR_VITORIA_2023\P2_M_GANDHI\20230615.CSV"
file_path = r"\\192.168.205.117\AAC_Server\TRAFICO\REGISTRO_RADAR_VITORIA_2023\P2_M_GANDHI\20230616.CSV"
df = pd.read_csv(file_path, sep=";")
df.head()
# Out:
#        Date      Time    Type Direction  Speed
# 0  16/06/23  00:02:06  Type 2       Out     25
# 1  16/06/23  00:03:38  Type 2        In     19
# 2  16/06/23  00:05:27  Type 2       Out     51
# 3  16/06/23  00:06:40  Type 1       Out     73
# 4  16/06/23  00:07:10  Type 2        In     41

# %% [markdown]
# el 95% de las detecciones son de vehiculos tipo turismo, y 3% para camiones

# %%
df["datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"], format="%d/%m/%y %H:%M:%S")

# Delay con respecto a sonómetro
# df["datetime"] = df["datetime"] + pd.Timedelta("25S")

df
# Out:
#           Date      Time    Type Direction  Speed            datetime
# 0     16/06/23  00:02:06  Type 2       Out     25 2023-06-16 00:02:06
# 1     16/06/23  00:03:38  Type 2        In     19 2023-06-16 00:03:38
# 2     16/06/23  00:05:27  Type 2       Out     51 2023-06-16 00:05:27
# 3     16/06/23  00:06:40  Type 1       Out     73 2023-06-16 00:06:40
# 4     16/06/23  00:07:10  Type 2        In     41 2023-06-16 00:07:10
# ...        ...       ...     ...       ...    ...                 ...
# 4173  16/06/23  23:57:17  Type 2        In     33 2023-06-16 23:57:17
# 4174  16/06/23  23:57:30  Type 2        In     40 2023-06-16 23:57:30
# 4175  16/06/23  23:58:38  Type 2        In     24 2023-06-16 23:58:38
# 4176  16/06/23  23:59:19  Type 2        In     40 2023-06-16 23:59:19
# 4177  16/06/23  23:59:59  Type 2        In     52 2023-06-16 23:59:59
#
# [4178 rows x 6 columns]

# %%
df["Type"].value_counts(normalize=True)
# Out:
# Type 2    0.940881
# Type 1    0.051699
# Type 3    0.006702
# Type 4    0.000718
# Name: Type, dtype: float64

# %%
# printing the max speed and the min speed
print("Max speed: ", df["Speed"].max())
print("Min speed: ", df["Speed"].min())
# Out:
# Max speed:  96
# Min speed:  8

# %%
# plot the speed distribution in a histogram plot using seaborn
sns.distplot(df["Speed"], bins=20, kde=False)
# Out:
# c:\Users\GIS2\.conda\envs\inference\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='Speed'>

# %%
# plotting the speed over time. using speed column as y-axis and time column as x-axis, and using matplotlib to plot the graph with a color gradient for the speed
plt.figure(figsize=(20, 10))

plt.scatter(df["datetime"], df["Speed"], c=df["Speed"], cmap="inferno")
plt.colorbar()
plt.ylabel("Speed (km/h)")
plt.xlabel("Time")
plt.show()

# %%
# plot by the color and the speed the type of vehicle 
# add color for the different types of vehicles
sns.catplot(data=df, x="Type",y="Speed", hue="Type", palette="Set2")

# %% [markdown]
# #  1 LECTURA DE DATOS NIVELES DE RUIDO

# %% [markdown]
# # SPL LA

# %%
# df_noise = pd.read_csv("Audiomoth2_Tanis_Aguirrebengoa_20230203_spl.csv",parse_dates=["date"])
# df_noise = pd.read_csv("Audiomoth2_Tanis_Aguirrebengoa_20230615_spl.csv", parse_dates=["date"])

noise_file_path = r"E:\AUDIOS_ID\2023\TRÁFICO\Vitoria_Radar\P2_M_GANDHI\Medidas_Audio_MothP2_spl.csv"

df_noise = pd.read_csv(noise_file_path, parse_dates=["date"])

df_noise
# Out:
#            LA     LC     LZ  LAmax  LAmin             filename  \
# 0       65.82  70.30  70.50  68.72  61.73  20230615_124441.wav
# 1       66.60  71.16  71.51  68.43  64.55  20230615_124441.wav
# 2       66.89  71.34  71.73  72.43  63.75  20230615_124441.wav
# 3       67.24  70.71  70.88  69.92  59.01  20230615_124441.wav
# 4       77.16  81.24  81.32  84.34  58.22  20230615_124441.wav
# ...       ...    ...    ...    ...    ...                  ...
# 602625  52.51  60.14  60.73  55.99  48.08  20230622_130340.wav
# 602626  53.17  61.19  61.66  55.21  51.19  20230622_130340.wav
# 602627  54.77  62.17  62.60  55.93  52.78  20230622_130340.wav
# 602628  77.93  81.15  81.25  85.00  55.75  20230622_130340.wav
# 602629  61.70  70.78  71.25  63.67  59.64  20230622_130340.wav
#
#                       date
# 0      2023-06-15 12:44:41
# 1      2023-06-15 12:44:42
# 2      2023-06-15 12:44:43
# 3      2023-06-15 12:44:44
# 4      2023-06-15 12:44:45
# ...                    ...
# 602625 2023-06-22 13:18:35
# 602626 2023-06-22 13:18:36
# 602627 2023-06-22 13:18:37
# 602628 2023-06-22 13:18:38
# 602629 2023-06-22 13:18:39
#
# [602630 rows x 7 columns]

# %%
# this is for the privious one

# df_noise["date"] = df_noise["date"] + pd.Timedelta("1H")

# df_noise

# %% [markdown]
# Inicilamente se usa el campo que contiene la información de los timestamps de las detecciónes para
# unir los datos de la estación de aforos con los niveles de ruido. Como la longitud de los datos
# de ruido no es igual a la de los datos de los aforos, se realiza una union “izquierda” en donde se
# conservan los datos de la tabla izquierda(ruido) y solo se unen los datos de aforo en los campos
# coincidentes.

# %%
df_join = pd.merge(df_noise, df, left_on="date", right_on="datetime", how="left")
df_join
# Out:
#            LA     LC     LZ  LAmax  LAmin             filename  \
NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-15 12:44:42  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-15 12:44:43  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-15 12:44:44  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-15 12:44:45  NaN  NaN  NaN       NaN    NaN      NaT
# ...                  ...  ...  ...       ...    ...      ...
# 2023-06-22 13:18:35  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-22 13:18:36  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-22 13:18:37  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-22 13:18:38  NaN  NaN  NaN       NaN    NaN      NaT
# 2023-06-22 13:18:39  NaN  NaN  NaN       NaN    NaN      NaT
#
# [602656 rows x 12 columns]

# %%
df_temp = df_join.loc["2023-06-16 13:50:44": "2023-06-16 13:55:44"]

levels = df_temp["LA"].values
speed = df_temp["Speed"].values

plt.figure(figsize=(15,6))

plt.plot(df_temp.index, levels);
plt.plot(df_temp.index, speed + 40, "*");

# %% [markdown]
# # Sonometro

# %%
df
# Out:
#           Date      Time    Type Direction  Speed            datetime
# 0     16/06/23  00:02:06  Type 2       Out     25 2023-06-16 00:02:06
# 1     16/06/23  00:03:38  Type 2        In     19 2023-06-16 00:03:38
# 2     16/06/23  00:05:27  Type 2       Out     51 2023-06-16 00:05:27
# 3     16/06/23  00:06:40  Type 1       Out     73 2023-06-16 00:06:40
# 4     16/06/23  00:07:10  Type 2        In     41 2023-06-16 00:07:10
# ...        ...       ...     ...       ...    ...                 ...
# 4173  16/06/23  23:57:17  Type 2        In     33 2023-06-16 23:57:17
# 4174  16/06/23  23:57:30  Type 2        In     40 2023-06-16 23:57:30
# 4175  16/06/23  23:58:38  Type 2        In     24 2023-06-16 23:58:38
# 4176  16/06/23  23:59:19  Type 2        In     40 2023-06-16 23:59:19
# 4177  16/06/23  23:59:59  Type 2        In     52 2023-06-16 23:59:59
#
# [4178 rows x 6 columns]

# %%
# add 2 min and 5 seconds to the datetime column
df["datetime"] = df["datetime"] + pd.Timedelta("2M") + pd.Timedelta("5S")
df["datetime"] = df["datetime"] + pd.Timedelta("5S")
df
# Out:
# c:\Users\GIS2\.conda\envs\inference\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Units 'M', 'Y' and 'y' do not represent unambiguous timedelta values and will be removed in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           Date      Time    Type Direction  Speed            datetime
# 0     16/06/23  00:02:06  Type 2       Out     25 2023-06-16 00:04:16
# 1     16/06/23  00:03:38  Type 2        In     19 2023-06-16 00:05:48
# 2     16/06/23  00:05:27  Type 2       Out     51 2023-06-16 00:07:37
# 3     16/06/23  00:06:40  Type 1       Out     73 2023-06-16 00:08:50
# 4     16/06/23  00:07:10  Type 2        In     41 2023-06-16 00:09:20
# ...        ...       ...     ...       ...    ...                 ...
# 4173  16/06/23  23:57:17  Type 2        In     33 2023-06-16 23:59:27
# 4174  16/06/23  23:57:30  Type 2        In     40 2023-06-16 23:59:40
# 4175  16/06/23  23:58:38  Type 2        In     24 2023-06-17 00:00:48
# 4176  16/06/23  23:59:19  Type 2        In     40 2023-06-17 00:01:29
# 4177  16/06/23  23:59:59  Type 2        In     52 2023-06-17 00:02:09
#
# [4178 rows x 6 columns]

# %%
noise_file_path = r"E:\AUDIOS_ID\2023\TRÁFICO\Vitoria_Radar\P2_M_GANDHI\LxT_0004545-20230615 125242-LxT_Data.464.xlsx"

# df_noise = pd.read_csv(noise_file_path, parse_dates=["date"])

df_noise = pd.read_excel(noise_file_path, sheet_name='Historia del tiempo')
df_noise.head()
# df_noise['date'] = pd.to_datetime(df['Fecha'])
# Out:
#    Registro # Tipo de registro               Fecha                Hora  LAeq  \
# 0           1           correr 2023-06-15 12:52:42 2023-06-15 12:52:42   NaN
# 1           2              NaN 2023-06-15 12:52:42 2023-06-15 12:52:42  53.9
# 2           3              NaN 2023-06-15 12:52:43 2023-06-15 12:52:43  56.2
# 3           4              NaN 2023-06-15 12:52:44 2023-06-15 12:52:44  57.7
# 4           5              NaN 2023-06-15 12:52:45 2023-06-15 12:52:45  61.7
#
#    LAFmax  LAFmin OVLD  Marcador  Comments
# 0     NaN     NaN  NaN       NaN       NaN
# 1    54.8    51.8   No       NaN       NaN
# 2    56.6    54.6   No       NaN       NaN
# 3    58.5    56.2   No       NaN       NaN
# 4    66.2    57.8   No       NaN       NaN

# %%
# 	LA	LC	LZ	LAmax	LAmin	filename	date
# 0	65.82	70.30	70.50	68.72	61.73	20230615_124441.wav	2023-06-15 13:44:41
# 1	66.60	71.16	71.51	68.43	64.55	20230615_124441.wav	2023-06-15 13:44:42

# %%
# df_noise["Fecha"] = df_noise["Fecha"] + pd.Timedelta("1H")

# df_noise

# %%
df_join = pd.merge(df_noise, df, left_on="Fecha", right_on="datetime", how="left")
df_join
# Out:
#         Registro # Tipo de registro               Fecha                Hora  \
# 0                1           correr 2023-06-15 12:52:42 2023-06-15 12:52:42
# 1                2              NaN 2023-06-15 12:52:42 2023-06-15 12:52:42
# 2                3              NaN 2023-06-15 12:52:43 2023-06-15 12:52:43
# 3                4              NaN 2023-06-15 12:52:44 2023-06-15 12:52:44
# 4                5              NaN 2023-06-15 12:52:45 2023-06-15 12:52:45
# ...            ...              ...                 ...                 ...
# 593284      593259              NaN 2023-06-22 09:40:19 2023-06-22 09:40:19
# 593285      593260              NaN 2023-06-22 09:40:20 2023-06-22 09:40:20
# 593286      593261              NaN 2023-06-22 09:40:21 2023-06-22 09:40:21
# 593287      593262              NaN 2023-06-22 09:40:22 2023-06-22 09:40:22
# 593288      593263          Detener 2023-06-22 09:40:23 2023-06-22 09:40:23
#
#         LAeq  LAFmax  LAFmin OVLD  Marcador  Comments Date Time Type  \
# 0        NaN     NaN     NaN  NaN       NaN       NaN  NaN  NaN  NaN
# 1       53.9    54.8    51.8   No       NaN       NaN  NaN  NaN  NaN
# 2       56.2    56.6    54.6   No       NaN       NaN  NaN  NaN  NaN
# 3       57.7    58.5    56.2   No       NaN       NaN  NaN  NaN  NaN
# 4       61.7    66.2    57.8   No       NaN       NaN  NaN  NaN  NaN
# ...      ...     ...     ...  ...       ...       ...  ...  ...  ...
# 593284  67.6    69.7    65.8   No       NaN       NaN  NaN  NaN  NaN
# 593285  62.9    65.8    61.6   No       NaN       NaN  NaN  NaN  NaN
# 593286  60.1    61.8    59.0   No       NaN       NaN  NaN  NaN  NaN
# 593287  58.5    59.0    58.7   No       NaN       NaN  NaN  NaN  NaN
# 593288   NaN     NaN     NaN  NaN       NaN       NaN  NaN  NaN  NaN
#
#        Direction  Speed datetime
# 0            NaN    NaN      NaT
# 1            NaN    NaN      NaT
# 2            NaN    NaN      NaT
# 3            NaN    NaN      NaT
# 4            NaN    NaN      NaT
# ...          ...    ...      ...
# 593284       NaN    NaN      NaT
# 593285       NaN    NaN      NaT
# 593286       NaN    NaN      NaT
# 593287       NaN    NaN      NaT
# 593288       NaN    NaN      NaT
#
# [593289 rows x 16 columns]

# %%
df_join = df_join.set_index("Fecha")
# df_temp = df_join.loc["2023-02-03 23:55:00":"2023-02-03 23:58:00"]

df_join.head()
# Out:
#                      Registro # Tipo de registro                Hora  LAeq  \
# Fecha
# 2023-06-15 12:52:42           1           correr 2023-06-15 12:52:42   NaN
# 2023-06-15 12:52:42           2              NaN 2023-06-15 12:52:42  53.9
# 2023-06-15 12:52:43           3              NaN 2023-06-15 12:52:43  56.2
# 2023-06-15 12:52:44           4              NaN 2023-06-15 12:52:44  57.7
# 2023-06-15 12:52:45           5              NaN 2023-06-15 12:52:45  61.7
#
#                      LAFmax  LAFmin OVLD  Marcador  Comments Date Time Type  \
# Fecha
# 2023-06-15 12:52:42     NaN     NaN  NaN       NaN       NaN  NaN  NaN  NaN
# 2023-06-15 12:52:42    54.8    51.8   No       NaN       NaN  NaN  NaN  NaN
# 2023-06-15 12:52:43    56.6    54.6   No       NaN       NaN  NaN  NaN  NaN
# 2023-06-15 12:52:44    58.5    56.2   No       NaN       NaN  NaN  NaN  NaN
# 2023-06-15 12:52:45    66.2    57.8   No       NaN       NaN  NaN  NaN  NaN
#
#                     Direction  Speed datetime
# Fecha
# 2023-06-15 12:52:42       NaN    NaN      NaT
# 2023-06-15 12:52:42       NaN    NaN      NaT
# 2023-06-15 12:52:43       NaN    NaN      NaT
# 2023-06-15 12:52:44       NaN    NaN      NaT
# 2023-06-15 12:52:45       NaN    NaN      NaT

# %%
df_temp = df_join.loc["2023-06-16 05:00:00": "2023-06-16 05:30:00"]

levels = df_temp["LAeq"].values

# make log 10 of all speed values
speed = df_temp["Speed"].values
speed_log_scaled = 10 * np.log10(speed + 1)

plt.figure(figsize=(20,10))
plt.plot(df_temp.index, levels);
plt.plot(df_temp.index, speed + 15, "*");

# %% [markdown]
# # 1.1 Selección de pass bys
# Se seleccionan aquellas detecciones que tiene un espacio mayor a 10 segundos con la detección
# anteior y la siguiente

# %%
sadfgsfd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_968/2780987146.py in <module>
# ----> 1 sadfgsfd
#
# NameError: name 'sadfgsfd' is not defined

# %%
df_car_detections = df_join[~df_join["Speed"].isna()].copy()
df_car_detections
# Out:
#                      Registro # Tipo de registro                Hora  LAeq  \
# Fecha
# 2023-06-16 00:04:16       40296              NaN 2023-06-16 00:04:16  60.3
# 2023-06-16 00:05:48       40388              NaN 2023-06-16 00:05:48  56.8
# 2023-06-16 00:07:37       40497              NaN 2023-06-16 00:07:37  65.0
# 2023-06-16 00:08:50       40570              NaN 2023-06-16 00:08:50  77.0
# 2023-06-16 00:09:20       40600              NaN 2023-06-16 00:09:20  61.2
# ...                         ...              ...                 ...   ...
# 2023-06-16 23:59:27      126407              NaN 2023-06-16 23:59:27  61.9
# 2023-06-16 23:59:40      126420              NaN 2023-06-16 23:59:40  57.5
# 2023-06-17 00:00:48      126488              NaN 2023-06-17 00:00:48  45.2
# 2023-06-17 00:01:29      126529              NaN 2023-06-17 00:01:29  54.0
# 2023-06-17 00:02:09      126569              NaN 2023-06-17 00:02:09  57.9
#
#                      LAFmax  LAFmin OVLD  Marcador  Comments      Date  \
# Fecha
# 2023-06-16 00:04:16    60.9    58.7   No       NaN       NaN  16/06/23
# 2023-06-16 00:05:48    57.2    55.6   No       NaN       NaN  16/06/23
# 2023-06-16 00:07:37    66.1    62.3   No       NaN       NaN  16/06/23
# 2023-06-16 00:08:50    80.5    66.6   No       NaN       NaN  16/06/23
# 2023-06-16 00:09:20    62.0    59.0   No       NaN       NaN  16/06/23
# ...                     ...     ...  ...       ...       ...       ...
# 2023-06-16 23:59:27    64.6    53.7   No       NaN       NaN  16/06/23
# 2023-06-16 23:59:40    59.1    56.1   No       NaN       NaN  16/06/23
# 2023-06-17 00:00:48    46.4    43.9   No       NaN       NaN  16/06/23
# 2023-06-17 00:01:29    55.0    52.1   No       NaN       NaN  16/06/23
# 2023-06-17 00:02:09    58.8    56.8   No       NaN       NaN  16/06/23
#
#                          Time    Type Direction  Speed            datetime
# Fecha
# 2023-06-16 00:04:16  00:02:06  Type 2       Out   25.0 2023-06-16 00:04:16
# 2023-06-16 00:05:48  00:03:38  Type 2        In   19.0 2023-06-16 00:05:48
# 2023-06-16 00:07:37  00:05:27  Type 2       Out   51.0 2023-06-16 00:07:37
# 2023-06-16 00:08:50  00:06:40  Type 1       Out   73.0 2023-06-16 00:08:50
# 2023-06-16 00:09:20  00:07:10  Type 2        In   41.0 2023-06-16 00:09:20
# ...                       ...     ...       ...    ...                 ...
# 2023-06-16 23:59:27  23:57:17  Type 2        In   33.0 2023-06-16 23:59:27
# 2023-06-16 23:59:40  23:57:30  Type 2        In   40.0 2023-06-16 23:59:40
# 2023-06-17 00:00:48  23:58:38  Type 2        In   24.0 2023-06-17 00:00:48
# 2023-06-17 00:01:29  23:59:19  Type 2        In   40.0 2023-06-17 00:01:29
# 2023-06-17 00:02:09  23:59:59  Type 2        In   52.0 2023-06-17 00:02:09
#
# [4178 rows x 15 columns]

# %%
df_car_detections = df_join[~df_join["Speed"].isna()].copy()
df_car_detections["left"] = df_car_detections["datetime"].shift()
df_car_detections["right"] = df_car_detections["datetime"].shift(-1)
df_car_detections["diff_left"] = df_car_detections["datetime"] - df_car_detections["left"]
df_car_detections["diff_right"] = df_car_detections["right"] - df_car_detections["datetime"]

# Select clean pass bys
df_clean_pass_by = df_car_detections[ (df_car_detections["diff_left"] > "10s") & (df_car_detections["diff_right"] > "10s") ].copy()
#                                    left               right       diff_left  \
# Fecha
# 2023-06-16 00:05:48 2023-06-16 00:04:16 2023-06-16 00:07:37 0 days 00:01:32
# 2023-06-16 00:07:37 2023-06-16 00:05:48 2023-06-16 00:08:50 0 days 00:01:49
# 2023-06-16 00:08:50 2023-06-16 00:07:37 2023-06-16 00:09:20 0 days 00:01:13
# 2023-06-16 00:09:20 2023-06-16 00:08:50 2023-06-16 00:10:14 0 days 00:00:30
# 2023-06-16 00:10:14 2023-06-16 00:09:20 2023-06-16 00:10:54 0 days 00:00:54
# ...                                 ...                 ...             ...
# 2023-06-16 23:58:27 2023-06-16 23:56:20 2023-06-16 23:59:27 0 days 00:02:07
# 2023-06-16 23:59:27 2023-06-16 23:58:27 2023-06-16 23:59:40 0 days 00:01:00
# 2023-06-16 23:59:40 2023-06-16 23:59:27 2023-06-17 00:00:48 0 days 00:00:13
# 2023-06-17 00:00:48 2023-06-16 23:59:40 2023-06-17 00:01:29 0 days 00:01:08
# 2023-06-17 00:01:29 2023-06-17 00:00:48 2023-06-17 00:02:09 0 days 00:00:41
#
#                          diff_right
# Fecha
# 2023-06-16 00:05:48 0 days 00:01:49
# 2023-06-16 00:07:37 0 days 00:01:13
# 2023-06-16 00:08:50 0 days 00:00:30
# 2023-06-16 00:09:20 0 days 00:00:54
# 2023-06-16 00:10:14 0 days 00:00:40
# ...                             ...
# 2023-06-16 23:58:27 0 days 00:01:00
# 2023-06-16 23:59:27 0 days 00:00:13
# 2023-06-16 23:59:40 0 days 00:01:08
# 2023-06-17 00:00:48 0 days 00:00:41
# 2023-06-17 00:01:29 0 days 00:00:40
#
# [1115 rows x 19 columns]

# %% [markdown]
# Usando estas detecciones se calcula el nivel exposición sonora con los datos de ruido y se grafican
# los niveles para comprpbar que corresponden con las formas de onda tipicas de pass by. Se puede
# observar que la mayoria siguen en este patrón aunque existen otras tantas que difieren del patrón
# tipico de pass-by

# %%
pass_by_width_seconds = 10 # time window in seconds  each pass by event to consider
sel_pass = []

i = 0
plt.figure(figsize=(20,8))

for date_paso, pass_by in df_clean_pass_by.iterrows():
    # df_temp is each pass-by selects data from df_join within a 15-second window before and after the pass-by time 
    df_temp = df_join.loc[date_paso - pd.Timedelta(f"{pass_by_width_seconds}s"): date_paso + pd.Timedelta(f"{pass_by_width_seconds}s") ]

    levels = df_temp["LAeq"] # levels is the LAeq values for the pass-by
    sel_pass.append(leq(levels) + np.log(8)) # calculate the sel for the pass-by and append it to the sel_pass list
    
    # plot the laeq values for the pass-by
    plt.plot(levels.values, linewidth=0.15)
    #i+=
    if i == 5:
        break

plt.xlabel("seconds")
plt.ylabel("LAeq1s")
plt.show()

df_clean_pass_by["SEL"] = sel_pass

# %% [markdown]
# Finalmente se puede observar la relación entre velocidad y SEL de los datos recogidos con el pass
# by automático

# %%
sns.jointplot(data=df_clean_pass_by, x="Speed", y = "SEL")

# %%
sns.jointplot(data=df_clean_pass_by, x="Speed", y = "SEL", kind="hex", color="#4CB391");

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
import plotly.express as px
from scipy.signal import find_peaks
import os
from pydub import AudioSegment

import params as yamnet_params
import yamnet as yamnet_model
import soundfile as sf
import resampy

# custom functions to perfomr Leq and db sum
def sum_levels(levels):
    l = np.array(levels)
    return 10*np.log10(np.sum(np.power(10,l/10)))

def leq(levels):
    l = np.array(levels)
    return 10*np.log10(np.mean(np.power(10,l/10)))
# Out:
# c:\Users\scjaa\anaconda3\envs\tensorflow_gpu_11_2\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# opne csv file
csv_file = r"\\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\leq_levels_P1_CONTENEDORES_v1_1_test.csv"
df = pd.read_csv(csv_file)
title = csv_file.split("\\")[-3]

# get the audiomoth folder
audiomoth_folder = csv_file.replace("5-Resultados","3-Medidas").replace("SPL","AUDIOMOTH")
# remove last item from audio moth folder
audiomoth_folder = "\\".join(audiomoth_folder.split("\\")[:-1])

output_folder = csv_file.split("\\")[:-1]
# join the folder
output_folder = "\\".join(output_folder)
print(output_folder)
# add 
if not os.path.exists(output_folder):
    print("Creating folder")
else:
    print("Folder already exists")

# # # chagen the filename to the full path
df['filename'] = df['filename'].apply(lambda x: os.path.join(audiomoth_folder, x))
df
# Out:
# \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL
# Folder already exists
#            LA     LC     LZ  LAmax  LAmin  \
# 0       72.07  79.36  79.97  73.09  70.91
# 1       72.40  79.43  79.86  73.70  71.27
# 2       72.16  78.31  78.61  73.06  71.27
# 3       72.38  78.21  78.32  73.86  70.97
# 4       71.70  77.32  77.41  72.21  71.26
# ...       ...    ...    ...    ...    ...
# 714003  70.90  77.58  77.77  73.48  68.05
# 714004  70.41  76.66  76.79  73.97  67.94
# 714005  67.92  74.28  74.41  69.86  66.57
# 714006  68.78  74.67  74.79  71.63  66.69
# 714007  76.70  83.61  83.83  78.78  71.75
#
#                                                  filename                 date
# 0       \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-11 14:04:20
# 1       \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-11 14:04:21
# 2       \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-11 14:04:22
# 3       \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-11 14:04:23
# 4       \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-11 14:04:24
# ...                                                   ...                  ...
# 714003  \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-20 06:21:15
# 714004  \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-20 06:21:16
# 714005  \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-20 06:21:17
# 714006  \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-20 06:21:18
# 714007  \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT...  2023-12-20 06:21:19
#
# [714008 rows x 7 columns]

# %%
# convert date column in datetime
df['date'] = pd.to_datetime(df['date'])

duration = df['date'].iloc[-1] - df['date'].iloc[0]
duration = duration.total_seconds()
print(f"Duration: {duration} seconds, {duration/60} minutes, {duration/3600} hours, {duration/3600/24} days")

la = df['LA'].values
print('\nMax:', np.max(la).round(2))
print('Min:', np.min(la).round(2))

print('\nMediana:', np.median(la).round(2))
print('Promedio:', leq(la).round(2))
print('Standard deviation:', np.std(la).round(2))

print('\nPercentil 98:', np.quantile(la, 0.99).round(2)) # percentil 98 means that 98% of the data is below this value
# Out:
# Duration: 749819.0 seconds, 12496.983333333334 minutes, 208.28305555555556 hours, 8.678460648148148 days
#
# Max: 96.9
# Min: 55.77
#
# Mediana: 67.47
# Promedio: 72.69
# Standard deviation: 5.5
#
# Percentil 98: 82.8

# %%
def save_clips_from_peaks(df, output_folder, sampling_rate):
    csv_output_folder = output_folder
    # if output folder does not exist, create it
    output_folder = os.path.join(output_folder, "peak_clips")
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for index, row in df.iterrows():
        audio_file = row['filename']
        start_time_seconds = row['start_time']
        end_time_seconds = row['end_time']

        #loading audio file
        wav_data, sr = sf.read(audio_file, dtype='int16')
        waveform = wav_data / 32768.0  # Convert to [-1.0, +1.0]

        
        print(f"Processing audio file: {audio_file}")
        print(f"Starting time: {start_time_seconds} seconds, Ending time: {end_time_seconds} seconds")
        
        # milliseconds
        start_time_ms = int(start_time_seconds * 1000)
        end_time_ms = int(end_time_seconds * 1000)
        print(f"Starting time milliseconds: {start_time_ms}, Ending time milliseconds: {end_time_ms}")


        # audio = AudioSegment.from_file(audio_file)
        clip = waveform[start_time_ms : end_time_ms]
        waveform = waveform.astype('float32')

        if len(waveform.shape) > 1:
            waveform = np.mean(waveform, axis=1)
        if sr != params.sample_rate:
            waveform = resampy.resample(waveform, sr, params.sample_rate)
        
        scores, embeddings, spectrogram = yamnet(waveform)
        prediction = np.mean(scores, axis=0)
        top3_i = np.argsort(prediction)[::-1][:3]

        print()
        print(clip, ':\n' +
          '\n'.join('  {:12s}: {:.3f}'.format(yamnet_classes[i], prediction[i])
                    for i in top3_i))
        print()

        # save a dataframe with the filename, start time, end time, and the top 3 classes
        filename = audio_file.split("\\")[-1]
        df_clip = pd.DataFrame({
            'filename': filename,
            'start_time': [start_time_seconds],
            'end_time': [end_time_seconds],
            'predicitons': [', '.join([yamnet_classes[i] for i in top3_i])],
            'probabilities': [', '.join([str(prediction[i]) for i in top3_i])],
        })

        # save the dataframe to a csv file
        csv_filename = f'peak_predictions_L50_{title}.csv'
        csv_path = os.path.join(csv_output_folder, csv_filename)
        # save to csv with the header only if the file does not exist
        df_clip.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
        print(f"Saving predictions to {csv_path}")

        print(f"Filename: {filename}")
        clip_path = os.path.join(output_folder, f"{filename}_peak_{yamnet_classes[top3_i[0]]}.wav")
        print(f"Saving clip {clip_path}")
        print(f"Clip duration: {len(clip)} milliseconds")  # debugging 

        # using sf.write to save the clip
        sf.write(clip_path, clip, sampling_rate)



params = yamnet_params.Params()
yamnet = yamnet_model.yamnet_frames_model(params)
yamnet.load_weights('yamnet.h5')
yamnet_classes = yamnet_model.class_names('yamnet_class_map.csv')

window_size = 30  # seconds
prominence = 1
width = 1

df['LA_median'] = df['LA'].rolling(window=window_size, min_periods=1).quantile(0.5) + 10

# go through each day
start_date = df['date'].dt.normalize().iloc[0]
end_date = df['date'].dt.normalize().iloc[-1]
current_date = start_date

peaks_num = []
while current_date <= end_date:
    daily_data = df[(df['date'] >= current_date) & (df['date'] < current_date + pd.Timedelta(days=1))]
    
    #dynamic threshold by filtering data points
    above_threshold = daily_data[daily_data['LA'] > daily_data['LA_median']]
    
    #find peaks in the filtered data
    if not above_threshold.empty:
        peaks, properties = find_peaks(above_threshold['LA'], prominence=prominence, width=width)
        peak_filenames = above_threshold.iloc[peaks]['filename'].values
        start_times = np.round(properties['left_ips'] ,2)
        end_times = np.round(properties['right_ips'], 2)
        
        #df for each peak
        peaks_df = pd.DataFrame({
            'filename': peak_filenames,
            'start_time': start_times,
            'end_time': end_times
        })

        # take the sr from the first audio file
        audio_file = peak_filenames[0]
        audio = AudioSegment.from_file(audio_file)
        sampling_rate = audio.frame_rate
        
        # SAVING CLIPS FROM PEAKS
        save_clips_from_peaks(peaks_df, output_folder, sampling_rate)
# Out:
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_140420.WAV
# Starting time: 3.95 seconds, Ending time: 6.5 seconds
# Starting time milliseconds: 3950, Ending time milliseconds: 6500
#
# [ 0.01315308  0.0241394   0.03451538 ... -0.03085327 -0.02420044
#  -0.02230835] :
#   Vehicle     : 0.489
#   Aircraft    : 0.160
#   Fixed-wing aircraft, airplane: 0.122
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_140420.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_140420.WAV_peak_Vehicle.wav
# Clip duration: 2550 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_140420.WAV
# Starting time: 8.66 seconds, Ending time: 10.53 seconds
# Starting time milliseconds: 8660, Ending time milliseconds: 10530
#
# [0.14181519 0.14916992 0.15426636 ... 0.0352478  0.03369141 0.03268433] :
#   Vehicle     : 0.489
#   Aircraft    : 0.160
#   Fixed-wing aircraft, airplane: 0.122
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_140420.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_140420.WAV_peak_Vehicle.wav
# Clip duration: 1870 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_140420.WAV
# Starting time: 12.8 seconds, Ending time: 15.98 seconds
# Starting time milliseconds: 12800, Ending time milliseconds: 15980
#
# [0.11148071 0.10864258 0.10186768 ... 0.04559326 0.04708862 0.04763794] :
#   Vehicle     : 0.489
#   Aircraft    : 0.160
#   Fixed-wing aircraft, airplane: 0.122
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_140420.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_140420.WAV_peak_Vehicle.wav
# Clip duration: 3180 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_141925.WAV
# Starting time: 19.74 seconds, Ending time: 22.55 seconds
# Starting time milliseconds: 19740, Ending time milliseconds: 22550
#
# [-0.13473511 -0.12460327 -0.11090088 ... -0.09707642 -0.09249878
#  -0.09033203] :
#   Vehicle     : 0.453
#   Aircraft    : 0.080
#   Rail transport: 0.066
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_141925.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_141925.WAV_peak_Vehicle.wav
# Clip duration: 2810 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_141925.WAV
# Starting time: 26.59 seconds, Ending time: 29.9 seconds
# Starting time milliseconds: 26590, Ending time milliseconds: 29900
#
# [0.0222168  0.01641846 0.01095581 ... 0.12271118 0.11254883 0.09698486] :
#   Vehicle     : 0.453
#   Aircraft    : 0.080
#   Rail transport: 0.066
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_141925.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_141925.WAV_peak_Vehicle.wav
# Clip duration: 3310 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_141925.WAV
# Starting time: 33.66 seconds, Ending time: 35.62 seconds
# Starting time milliseconds: 33660, Ending time milliseconds: 35620
#
# [0.04458618 0.0496521  0.0531311  ... 0.0055542  0.01449585 0.02362061] :
#   Vehicle     : 0.453
#   Aircraft    : 0.080
#   Rail transport: 0.066
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_141925.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_141925.WAV_peak_Vehicle.wav
# Clip duration: 1960 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_141925.WAV
# Starting time: 38.83 seconds, Ending time: 41.5 seconds
# Starting time milliseconds: 38830, Ending time milliseconds: 41500
#
# [0.06930542 0.07138062 0.0713501  ... 0.01119995 0.01049805 0.01095581] :
#   Vehicle     : 0.453
#   Aircraft    : 0.080
#   Rail transport: 0.066
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_141925.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_141925.WAV_peak_Vehicle.wav
# Clip duration: 2670 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_141925.WAV
# Starting time: 43.21 seconds, Ending time: 47.44 seconds
# Starting time milliseconds: 43210, Ending time milliseconds: 47440
#
# [ 0.06521606  0.05758667  0.05255127 ... -0.16317749 -0.18099976
#  -0.19448853] :
#   Vehicle     : 0.453
#   Aircraft    : 0.080
#   Rail transport: 0.066
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_141925.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_141925.WAV_peak_Vehicle.wav
# Clip duration: 4230 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_144935.WAV
# Starting time: 51.35 seconds, Ending time: 53.67 seconds
# Starting time milliseconds: 51350, Ending time milliseconds: 53670
#
# [-0.02316284 -0.00308228  0.01153564 ...  0.05728149  0.06402588
#   0.0741272 ] :
#   Vehicle     : 0.365
#   Music       : 0.111
#   Rail transport: 0.074
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_144935.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_144935.WAV_peak_Vehicle.wav
# Clip duration: 2320 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_150440.WAV
# Starting time: 58.42 seconds, Ending time: 59.5 seconds
# Starting time milliseconds: 58420, Ending time milliseconds: 59500
#
# [-0.03317261 -0.03323364 -0.03311157 ... -0.05349731 -0.05758667
#  -0.06072998] :
#   Vehicle     : 0.365
#   Aircraft    : 0.101
#   Fixed-wing aircraft, airplane: 0.071
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_150440.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_150440.WAV_peak_Vehicle.wav
# Clip duration: 1080 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_150440.WAV
# Starting time: 60.84 seconds, Ending time: 62.92 seconds
# Starting time milliseconds: 60840, Ending time milliseconds: 62920
#
# [0.10681152 0.11212158 0.1171875  ... 0.0715332  0.07754517 0.08285522] :
#   Vehicle     : 0.365
#   Aircraft    : 0.101
#   Fixed-wing aircraft, airplane: 0.071
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_150440.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_150440.WAV_peak_Vehicle.wav
# Clip duration: 2080 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 71.15 seconds, Ending time: 72.75 seconds
# Starting time milliseconds: 71150, Ending time milliseconds: 72750
#
# [-0.06140137 -0.06246948 -0.06240845 ...  0.05065918  0.05258179
#   0.05099487] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 1600 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 77.06 seconds, Ending time: 78.5 seconds
# Starting time milliseconds: 77060, Ending time milliseconds: 78500
#
# [ 0.00958252  0.01702881  0.0229187  ... -0.05996704 -0.06268311
#  -0.06411743] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 1440 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 83.62 seconds, Ending time: 85.5 seconds
# Starting time milliseconds: 83620, Ending time milliseconds: 85500
#
# [ 0.02908325  0.02630615  0.02182007 ... -0.1204834  -0.12219238
#  -0.12060547] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 1880 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 90.33 seconds, Ending time: 92.28 seconds
# Starting time milliseconds: 90330, Ending time milliseconds: 92280
#
# [-0.00033569 -0.00680542 -0.01324463 ... -0.01654053 -0.02432251
#  -0.03207397] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 1950 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 94.32 seconds, Ending time: 96.73 seconds
# Starting time milliseconds: 94320, Ending time milliseconds: 96730
#
# [0.00262451 0.00674438 0.012146   ... 0.01507568 0.01104736 0.00610352] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 2410 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 99.05 seconds, Ending time: 100.5 seconds
# Starting time milliseconds: 99050, Ending time milliseconds: 100500
#
# [ 0.01358032  0.01309204  0.01016235 ... -0.08651733 -0.08813477
#  -0.09191895] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 1450 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_151945.WAV
# Starting time: 102.17 seconds, Ending time: 104.72 seconds
# Starting time milliseconds: 102170, Ending time milliseconds: 104720
#
# [4.02832031e-03 2.34985352e-03 6.10351562e-05 ... 2.53601074e-02
#  2.32543945e-02 2.09655762e-02] :
#   Vehicle     : 0.372
#   Aircraft    : 0.113
#   Fixed-wing aircraft, airplane: 0.083
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_151945.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_151945.WAV_peak_Vehicle.wav
# Clip duration: 2550 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 105.93 seconds, Ending time: 107.83 seconds
# Starting time milliseconds: 105930, Ending time milliseconds: 107830
#
# [-0.03588867 -0.03381348 -0.03286743 ...  0.12319946  0.11923218
#   0.11361694] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 1900 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 113.94 seconds, Ending time: 116.3 seconds
# Starting time milliseconds: 113940, Ending time milliseconds: 116300
#
# [0.15182495 0.15222168 0.15136719 ... 0.08929443 0.09228516 0.09182739] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 2360 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 123.47 seconds, Ending time: 124.5 seconds
# Starting time milliseconds: 123470, Ending time milliseconds: 124500
#
# [ 0.03128052  0.03121948  0.03308105 ... -0.00201416  0.00213623
#   0.00405884] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 1030 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 125.77 seconds, Ending time: 126.79 seconds
# Starting time milliseconds: 125770, Ending time milliseconds: 126790
#
# [ 0.025177    0.03097534  0.0362854  ... -0.04516602 -0.03979492
#  -0.03540039] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 1020 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 125.49 seconds, Ending time: 130.5 seconds
# Starting time milliseconds: 125490, Ending time milliseconds: 130500
#
# [ 0.03894043  0.03674316  0.03302002 ... -0.02404785 -0.02832031
#  -0.0324707 ] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 5010 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 133.36 seconds, Ending time: 134.84 seconds
# Starting time milliseconds: 133360, Ending time milliseconds: 134840
#
# [0.03656006 0.04177856 0.04718018 ... 0.06338501 0.06820679 0.07220459] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 1480 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 140.23 seconds, Ending time: 141.5 seconds
# Starting time milliseconds: 140230, Ending time milliseconds: 141500
#
# [ 0.03579712  0.0397644   0.04138184 ... -0.13595581 -0.13381958
#  -0.13027954] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 1270 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_153450.WAV
# Starting time: 143.47 seconds, Ending time: 146.11 seconds
# Starting time milliseconds: 143470, Ending time milliseconds: 146110
#
# [ 0.00384521 -0.00088501 -0.00350952 ... -0.0017395  -0.00091553
#  -0.00195312] :
#   Vehicle     : 0.385
#   Aircraft    : 0.115
#   Fixed-wing aircraft, airplane: 0.081
#
# Saving predictions to \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_predictions_L50_P1_CONTENEDORES.csv
# Filename: 20231211_153450.WAV
# Saving clip \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\5-Resultados\P1_CONTENEDORES\SPL\peak_clips\20231211_153450.WAV_peak_Vehicle.wav
# Clip duration: 2640 milliseconds
# Processing audio file: \\192.168.205.117\AAC_Server\PUERTOS\NOISEPORT\20231211_SANTUR\3-Medidas\P1_CONTENEDORES\AUDIOMOTH\20231211_154955.WAV
# Starting time: 147.5 seconds, Ending time: 149.38 seconds
# Starting time milliseconds: 147500, Ending time milliseconds: 149380

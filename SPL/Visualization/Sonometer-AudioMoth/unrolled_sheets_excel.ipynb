# %%
import pandas as pd
import os

# %%
excel_path = r"\\192.168.205.117\AAC_Server\OCIO\OCIO_BILBAO\CAMPAÑA_4\3-Medidas\Sonometro_bilbao\SONOMETRO\EQUIPOS 20-27 MARZO.xlsx"
excel_file = pd.read_excel(excel_path, sheet_name=None, header=4)
output_dir = os.path.dirname(excel_path)

print(output_dir)
output_dir = output_dir.split("\\")[:-2]
print(output_dir)
output_dir = "\\".join(output_dir)
print(output_dir)
# make sure the output directory exists
if not os.path.exists(output_dir):
    print(f"Created {output_dir} directory")
# Out:
# \\192.168.205.117\AAC_Server\OCIO\OCIO_BILBAO\CAMPAÑA_4\3-Medidas\Sonometro_bilbao\SONOMETRO
# ['', '', '192.168.205.117', 'AAC_Server', 'OCIO', 'OCIO_BILBAO', 'CAMPAÑA_4', '3-Medidas']
# \\192.168.205.117\AAC_Server\OCIO\OCIO_BILBAO\CAMPAÑA_4\3-Medidas

# %%
# list the sheet n
excel_sheets = list(excel_file.keys())
excel_sheets_count = len(excel_sheets)
print(f"Excel file has {excel_sheets_count} sheets \nwhich are {excel_sheets}\n")

for sheet in excel_sheets:
    excel_file[sheet] = excel_file[sheet][["Date", "Value"]]
    # rename Date to datetime
    excel_file[sheet] = excel_file[sheet].rename(columns={"Date":"datetime"})
    # convert to datetime
    excel_file[sheet]["datetime"] = pd.to_datetime(excel_file[sheet]["datetime"], dayfirst=True)
    # order by datetime
    excel_file[sheet] = excel_file[sheet].sort_values(by="datetime")
    # remove nan values
    excel_file[sheet] = excel_file[sheet].dropna()
    print(excel_file[sheet].head())

    # save each sheet as a csv fil
    output_file = f"{sheet}/SONOMETRO/"
    if not os.path.exists(os.path.join(output_dir, output_file)):
        os.makedirs(os.path.join(output_dir, output_file))
        print(f"Created {os.path.join(output_dir, output_file)} directory")

    # save to csv
    excel_file[sheet].to_csv(os.path.join(output_dir, output_file, f"{sheet}.csv"), index=False)
# Out:
# Excel file has 12 sheets
# which are ['BI-RUI-C002LD', 'BI-RUI-BR2LD', 'BI-RUI-C010LD', 'BI-RUI-C020LD', 'BI-RUI-C019LD', 'BI-RUI-C018LD', 'BI-RUI-C017LD', 'BI-RUI-C013LD', 'BI-RUI-020LD', 'BI-RUI-021LD', 'BI-RUI-022LD', 'BI-RUI-C032LD']
#
#              datetime  Value
# 0 2024-03-20 00:15:00  56.66
# 1 2024-03-20 00:30:00  56.28
# 2 2024-03-20 00:45:00  58.54
# 3 2024-03-20 01:00:00  59.62
# 4 2024-03-20 01:15:00  55.86
# Created \\192.168.205.117\AAC_Server\OCIO\OCIO_BILBAO\CAMPAÑA_4\3-Medidas\BI-RUI-C002LD/SONOMETRO/ directory
#              datetime  Value
# 0 2024-03